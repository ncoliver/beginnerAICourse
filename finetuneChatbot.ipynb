# %% [markdown]
# <a href="https://colab.research.google.com/github/ncoliver/beginnerAICourse/blob/main/finetuneChatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers datasets peft accelerate gradio
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: peft in /usr/local/lib/python3.12/dist-packages (0.17.1)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.10.1)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.48.1-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.35.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from peft) (2.8.0+cu126)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.10.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (3.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13.0->peft) (3.0.3)
# Downloading bitsandbytes-0.48.1-py3-none-manylinux_2_24_x86_64.whl (60.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 MB 44.6 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.48.1

# %%
# ✅ 2️⃣ Imports
from transformers import AutoModelForCausalLM, AutoTokenizer, TrainingArguments, Trainer
from datasets import load_dataset
from peft import LoraConfig, get_peft_model
import torch

# ✅ 3️⃣ Load model and tokenizer
model_name = "mistralai/Mistral-7B-Instruct-v0.2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token   # important for padding

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    load_in_8bit=True,
    device_map="auto"
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/596 [00:00<?, ?B/s]
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]

# %%
# ✅ 4️⃣ Load and preprocess dataset
dataset = load_dataset("json", data_files="basketball.json")

def tokenize(example):
    # Concatenate question and answer text
    text = example["question"] + "\n" + example["answer"] + tokenizer.eos_token
    tokenized = tokenizer(
        text,
        truncation=True,
        max_length=512,
        padding="max_length"
    )
    # Add labels for supervised fine-tuning
    tokenized["labels"] = tokenized["input_ids"].copy()
    return tokenized

tokenized_ds = dataset.map(tokenize)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/20 [00:00<?, ? examples/s]

# %%
# ✅ 5️⃣ Configure LoRA for parameter-efficient fine-tuning
lora_config = LoraConfig(
    r=8,
    lora_alpha=32,
    target_modules=["q_proj", "v_proj"],
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM"
)
model = get_peft_model(model, lora_config)

# %%
# ✅ 6️⃣ Define training arguments
training_args = TrainingArguments(
    output_dir="./chatbot_model",
    per_device_train_batch_size=1,
    gradient_accumulation_steps=4,
    num_train_epochs=100,  # start small; increase after verifying
    learning_rate=2e-4,
    fp16=True,
    logging_steps=10,
    save_strategy="epoch",
    optim="paged_adamw_8bit"  # memory-efficient optimizer
)

# %%
# ✅ 7️⃣ Initialize Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_ds["train"]
)

# %%
# ✅ 8️⃣ Train
trainer.train()
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: ncoliver (ncoliver-mosu) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251019_221652-pplzxwr2</code>
# Syncing run <strong><a href='https://wandb.ai/ncoliver-mosu/huggingface/runs/pplzxwr2' target="_blank">rural-fire-3</a></strong> to <a href='https://wandb.ai/ncoliver-mosu/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ncoliver-mosu/huggingface' target="_blank">https://wandb.ai/ncoliver-mosu/huggingface</a>
#  View run at <a href='https://wandb.ai/ncoliver-mosu/huggingface/runs/pplzxwr2' target="_blank">https://wandb.ai/ncoliver-mosu/huggingface/runs/pplzxwr2</a>
#     <div>
#
#       <progress value='500' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [500/500 15:49, Epoch 100/100]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>5.515700</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>5.444200</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>5.323900</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>5.306400</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>5.276700</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>5.268800</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>5.279500</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>5.266000</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>5.279900</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>5.286800</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>5.257700</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>5.293600</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>5.307700</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>5.320200</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>5.268000</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>5.277500</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>5.291400</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>5.312700</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>5.258900</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>5.300900</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>5.266900</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>5.279200</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>5.289900</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>5.284900</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>5.271300</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>5.309300</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>5.281300</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>5.286000</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>5.292400</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>5.293100</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>5.256800</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>5.281700</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>5.292000</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>5.282100</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>5.215500</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>5.259600</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>5.226400</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>5.224800</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>5.220500</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>5.211800</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>5.220500</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>5.201300</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>5.246900</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>5.271900</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>5.263400</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>5.297000</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>5.267900</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>5.281100</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>5.275300</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>5.286000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=500, training_loss=5.28146346282959, metrics={'train_runtime': 1260.1853, 'train_samples_per_second': 1.587, 'train_steps_per_second': 0.397, 'total_flos': 4.3708833595392e+16, 'train_loss': 5.28146346282959, 'epoch': 100.0})

# %%
# ✅ Save the fine-tuned LoRA adapter
model.save_pretrained("./chatbot_model")
print("✅ LoRA adapter saved to ./chatbot_model")
# Out:
# ✅ LoRA adapter saved to ./chatbot_model

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
from peft import PeftModel

base_model_name = "mistralai/Mistral-7B-Instruct-v0.2"

# Load base model + tokenizer
tokenizer = AutoTokenizer.from_pretrained(base_model_name)
base_model = AutoModelForCausalLM.from_pretrained(
    base_model_name, device_map="auto", torch_dtype="auto"
)

# Load adapter (now exists!)
model = PeftModel.from_pretrained(base_model, "./chatbot_model")

pipe = pipeline("text-generation", model=model, tokenizer=tokenizer, device_map="auto")
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Device set to use cuda:0
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Explain basketball fouls: What are major and minor infractions?
# Major fouls disrupt play and give an advantage. They include shooting, driving, and defensive three seconds. Minor fouls are less severe, such as blocking, pushing, and lingering in the lane. Both affect play length and team reputation.

# %%
print(pipe("Explain systematic basketball:", max_new_tokens=150)[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Explain systematic basketball:systematic How is systematic basketball:systematic built?
# Systematic basketball:systematic is built from core principles, repeated until second nature. It’s structured like a pyramid, with fundamentals at the base supporting progressively advanced tactics.

# %%
def chatbot(prompt, chat_history=[]):
    """Generate model response given user input and prior conversation."""
    history_text = "\n".join([f"User: {u}\nAssistant: {a}" for u, a in chat_history])
    full_prompt = f"{history_text}\nUser: {prompt}\nAssistant:"

    output = pipe(
        full_prompt,
        max_new_tokens=200,
        do_sample=True,
        temperature=0.7,
        top_p=0.9,
        repetition_penalty=1.1
    )[0]["generated_text"]

    # Extract only the assistant part
    response = output.split("Assistant:")[-1].strip()
    chat_history.append((prompt, response))
    return chat_history, chat_history

# %%
def save_feedback(rating, comment):
    with open("feedback.csv", "a") as f:
        f.write(f"{rating},{comment}\n")
    return "⭐ Thanks for your feedback!"

with gr.Blocks() as demo:
    gr.Markdown("# Teaching Chatbot with Feedback")
    chat = gr.Chatbot()
    text = gr.Textbox(label="Ask me something!")
    text.submit(lambda m, h: (h + [(m, f"Response: {m}")], ""), [text, chat], [chat, text])

    gr.Markdown("## 💬 Rate your experience")
    rating = gr.Slider(1, 5, value=5, step=1, label="Rate (1=Poor, 5=Excellent)")
    comment = gr.Textbox(label="Optional comment")
    submit = gr.Button("Submit")
    output = gr.Textbox(label="Status", interactive=False)

    submit.click(save_feedback, [rating, comment], output)

demo.launch()
# Out:
# /tmp/ipython-input-1733990398.py:11: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chat = gr.Chatbot()
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://9a1c97574d77632c3f.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://9a1c97574d77632c3f.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# !pip install nbformat
# Out:
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from nbformat) (5.8.1)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.12/dist-packages (from nbformat) (5.7.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat) (0.27.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.5.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat) (4.15.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !zip -r /content/chatbot_model.zip /content/chatbot_model
# !mv /content/chatbot_model.zip /content/drive/MyDrive/chatbot_model.zip
# Out:
#   adding: content/chatbot_model/ (stored 0%)
#   adding: content/chatbot_model/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/runs/ (stored 0%)
#   adding: content/chatbot_model/runs/Oct19_22-11-43_f1abb24b1c58/ (stored 0%)
#   adding: content/chatbot_model/runs/Oct19_22-11-43_f1abb24b1c58/events.out.tfevents.1760911906.f1abb24b1c58.4027.0 (deflated 65%)
#   adding: content/chatbot_model/checkpoint-415/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-415/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-415/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-415/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-415/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-415/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-415/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-415/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-415/trainer_state.json (deflated 79%)
#   adding: content/chatbot_model/checkpoint-415/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-185/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-185/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-185/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-185/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-185/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-185/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-185/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-185/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-185/trainer_state.json (deflated 75%)
#   adding: content/chatbot_model/checkpoint-185/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-445/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-445/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-445/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-445/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-445/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-445/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-445/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-445/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-445/trainer_state.json (deflated 80%)
#   adding: content/chatbot_model/checkpoint-445/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-410/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-410/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-410/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-410/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-410/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-410/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-410/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-410/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-410/trainer_state.json (deflated 79%)
#   adding: content/chatbot_model/checkpoint-410/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-40/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-40/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-40/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-40/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-40/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-40/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-40/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-40/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-40/trainer_state.json (deflated 63%)
#   adding: content/chatbot_model/checkpoint-40/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-55/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-55/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-55/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-55/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-55/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-55/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-55/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-55/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-55/trainer_state.json (deflated 65%)
#   adding: content/chatbot_model/checkpoint-55/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-85/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-85/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-85/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-85/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-85/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-85/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-85/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-85/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-85/trainer_state.json (deflated 69%)
#   adding: content/chatbot_model/checkpoint-85/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-465/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-465/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-465/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-465/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-465/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-465/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-465/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-465/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-465/trainer_state.json (deflated 80%)
#   adding: content/chatbot_model/checkpoint-465/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-50/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-50/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-50/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-50/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-50/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-50/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-50/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-50/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-50/trainer_state.json (deflated 65%)
#   adding: content/chatbot_model/checkpoint-50/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-110/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-110/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-110/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-110/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-110/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-110/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-110/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-110/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-110/trainer_state.json (deflated 72%)
#   adding: content/chatbot_model/checkpoint-110/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-245/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-245/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-245/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-245/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-245/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-245/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-245/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-245/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-245/trainer_state.json (deflated 77%)
#   adding: content/chatbot_model/checkpoint-245/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-485/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-485/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-485/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-485/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-485/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-485/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-485/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-485/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-485/trainer_state.json (deflated 80%)
#   adding: content/chatbot_model/checkpoint-485/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-280/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-280/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-280/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-280/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-280/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-280/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-280/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-280/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-280/trainer_state.json (deflated 78%)
#   adding: content/chatbot_model/checkpoint-280/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-210/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-210/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-210/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-210/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-210/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-210/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-210/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-210/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-210/trainer_state.json (deflated 76%)
#   adding: content/chatbot_model/checkpoint-210/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-115/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-115/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-115/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-115/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-115/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-115/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-115/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-115/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-115/trainer_state.json (deflated 72%)
#   adding: content/chatbot_model/checkpoint-115/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-295/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-295/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-295/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-295/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-295/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-295/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-295/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-295/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-295/trainer_state.json (deflated 78%)
#   adding: content/chatbot_model/checkpoint-295/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-330/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-330/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-330/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-330/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-330/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-330/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-330/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-330/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-330/trainer_state.json (deflated 79%)
#   adding: content/chatbot_model/checkpoint-330/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-275/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-275/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-275/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-275/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-275/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-275/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-275/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-275/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-275/trainer_state.json (deflated 78%)
#   adding: content/chatbot_model/checkpoint-275/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-195/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-195/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-195/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-195/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-195/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-195/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-195/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-195/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-195/trainer_state.json (deflated 76%)
#   adding: content/chatbot_model/checkpoint-195/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-405/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-405/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-405/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-405/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-405/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-405/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-405/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-405/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-405/trainer_state.json (deflated 79%)
#   adding: content/chatbot_model/checkpoint-405/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-15/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-15/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-15/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-15/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-15/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-15/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-15/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-15/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-15/trainer_state.json (deflated 56%)
#   adding: content/chatbot_model/checkpoint-15/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-25/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-25/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-25/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-25/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-25/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-25/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-25/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-25/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-25/trainer_state.json (deflated 59%)
#   adding: content/chatbot_model/checkpoint-25/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-170/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-170/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-170/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-170/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-170/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-170/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-170/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-170/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-170/trainer_state.json (deflated 75%)
#   adding: content/chatbot_model/checkpoint-170/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-320/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-320/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-320/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-320/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-320/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-320/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-320/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-320/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-320/trainer_state.json (deflated 78%)
#   adding: content/chatbot_model/checkpoint-320/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-460/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-460/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-460/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-460/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-460/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-460/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-460/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-460/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-460/trainer_state.json (deflated 80%)
#   adding: content/chatbot_model/checkpoint-460/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-150/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-150/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-150/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-150/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-150/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-150/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-150/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-150/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-150/trainer_state.json (deflated 74%)
#   adding: content/chatbot_model/checkpoint-150/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-480/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-480/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-480/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-480/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-480/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-480/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-480/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-480/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-480/trainer_state.json (deflated 80%)
#   adding: content/chatbot_model/checkpoint-480/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-290/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-290/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-290/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-290/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-290/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-290/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-290/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-290/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-290/trainer_state.json (deflated 78%)
#   adding: content/chatbot_model/checkpoint-290/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-145/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-145/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-145/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-145/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-145/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-145/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-145/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-145/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-145/trainer_state.json (deflated 74%)
#   adding: content/chatbot_model/checkpoint-145/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-45/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-45/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-45/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-45/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-45/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-45/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-45/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-45/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-45/trainer_state.json (deflated 63%)
#   adding: content/chatbot_model/checkpoint-45/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-450/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-450/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-450/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-450/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-450/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-450/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-450/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-450/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-450/trainer_state.json (deflated 80%)
#   adding: content/chatbot_model/checkpoint-450/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-190/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-190/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-190/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-190/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-190/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-190/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-190/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-190/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-190/trainer_state.json (deflated 76%)
#   adding: content/chatbot_model/checkpoint-190/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-285/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-285/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-285/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-285/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-285/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-285/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-285/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-285/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-285/trainer_state.json (deflated 78%)
#   adding: content/chatbot_model/checkpoint-285/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-475/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-475/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-475/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-475/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-475/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-475/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-475/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-475/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-475/trainer_state.json (deflated 80%)
#   adding: content/chatbot_model/checkpoint-475/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-325/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-325/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-325/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-325/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-325/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-325/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-325/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-325/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-325/trainer_state.json (deflated 78%)
#   adding: content/chatbot_model/checkpoint-325/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-95/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-95/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-95/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-95/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-95/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-95/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-95/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-95/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-95/trainer_state.json (deflated 70%)
#   adding: content/chatbot_model/checkpoint-95/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-120/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-120/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-120/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-120/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-120/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-120/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-120/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-120/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-120/trainer_state.json (deflated 73%)
#   adding: content/chatbot_model/checkpoint-120/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-75/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-75/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-75/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-75/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-75/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-75/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-75/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-75/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-75/trainer_state.json (deflated 68%)
#   adding: content/chatbot_model/checkpoint-75/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-225/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-225/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-225/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-225/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-225/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-225/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-225/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-225/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-225/trainer_state.json (deflated 77%)
#   adding: content/chatbot_model/checkpoint-225/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-335/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-335/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-335/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-335/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-335/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-335/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-335/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-335/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-335/trainer_state.json (deflated 79%)
#   adding: content/chatbot_model/checkpoint-335/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-310/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-310/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-310/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-310/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-310/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-310/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-310/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-310/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-310/trainer_state.json (deflated 78%)
#   adding: content/chatbot_model/checkpoint-310/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-300/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-300/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-300/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-300/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-300/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-300/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-300/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-300/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-300/trainer_state.json (deflated 78%)
#   adding: content/chatbot_model/checkpoint-300/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-305/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-305/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-305/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-305/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-305/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-305/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-305/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-305/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-305/trainer_state.json (deflated 78%)
#   adding: content/chatbot_model/checkpoint-305/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-340/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-340/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-340/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-340/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-340/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-340/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-340/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-340/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-340/trainer_state.json (deflated 79%)
#   adding: content/chatbot_model/checkpoint-340/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-140/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-140/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-140/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-140/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-140/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-140/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-140/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-140/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-140/trainer_state.json (deflated 74%)
#   adding: content/chatbot_model/checkpoint-140/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-355/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-355/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-355/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-355/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-355/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-355/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-355/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-355/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-355/trainer_state.json (deflated 79%)
#   adding: content/chatbot_model/checkpoint-355/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-440/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-440/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-440/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-440/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-440/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-440/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-440/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-440/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-440/trainer_state.json (deflated 80%)
#   adding: content/chatbot_model/checkpoint-440/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-215/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-215/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-215/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-215/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-215/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-215/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-215/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-215/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-215/trainer_state.json (deflated 76%)
#   adding: content/chatbot_model/checkpoint-215/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-60/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-60/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-60/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-60/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-60/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-60/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-60/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-60/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-60/trainer_state.json (deflated 67%)
#   adding: content/chatbot_model/checkpoint-60/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-455/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-455/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-455/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-455/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-455/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-455/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-455/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-455/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-455/trainer_state.json (deflated 80%)
#   adding: content/chatbot_model/checkpoint-455/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-400/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-400/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-400/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-400/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-400/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-400/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-400/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-400/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-400/trainer_state.json (deflated 79%)
#   adding: content/chatbot_model/checkpoint-400/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-5/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-5/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-5/optimizer.pt (deflated 10%)
#   adding: content/chatbot_model/checkpoint-5/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-5/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-5/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-5/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-5/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-5/trainer_state.json (deflated 57%)
#   adding: content/chatbot_model/checkpoint-5/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-135/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-135/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-135/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-135/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-135/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-135/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-135/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-135/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-135/trainer_state.json (deflated 73%)
#   adding: content/chatbot_model/checkpoint-135/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-240/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-240/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-240/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-240/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-240/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-240/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-240/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-240/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-240/trainer_state.json (deflated 77%)
#   adding: content/chatbot_model/checkpoint-240/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-490/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-490/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-490/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-490/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-490/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-490/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-490/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-490/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-490/trainer_state.json (deflated 80%)
#   adding: content/chatbot_model/checkpoint-490/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-370/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-370/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-370/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-370/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-370/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-370/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-370/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-370/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-370/trainer_state.json (deflated 79%)
#   adding: content/chatbot_model/checkpoint-370/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-130/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-130/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-130/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-130/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-130/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-130/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-130/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-130/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-130/trainer_state.json (deflated 73%)
#   adding: content/chatbot_model/checkpoint-130/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-420/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-420/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-420/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-420/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-420/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-420/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-420/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-420/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-420/trainer_state.json (deflated 80%)
#   adding: content/chatbot_model/checkpoint-420/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-230/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-230/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-230/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-230/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-230/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-230/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-230/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-230/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-230/trainer_state.json (deflated 77%)
#   adding: content/chatbot_model/checkpoint-230/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-255/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-255/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-255/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-255/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-255/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-255/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-255/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-255/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-255/trainer_state.json (deflated 77%)
#   adding: content/chatbot_model/checkpoint-255/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-495/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-495/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-495/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-495/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-495/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-495/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-495/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-495/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-495/trainer_state.json (deflated 80%)
#   adding: content/chatbot_model/checkpoint-495/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-350/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-350/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-350/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-350/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-350/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-350/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-350/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-350/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-350/trainer_state.json (deflated 79%)
#   adding: content/chatbot_model/checkpoint-350/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-165/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-165/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-165/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-165/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-165/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-165/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-165/scheduler.pt (deflated 61%)
# ...
#   adding: content/chatbot_model/checkpoint-205/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-250/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-250/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-250/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-250/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-250/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-250/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-250/scheduler.pt (deflated 62%)
#   adding: content/chatbot_model/checkpoint-250/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-250/trainer_state.json (deflated 77%)
#   adding: content/chatbot_model/checkpoint-250/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-385/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-385/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-385/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-385/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-385/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-385/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-385/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-385/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-385/trainer_state.json (deflated 79%)
#   adding: content/chatbot_model/checkpoint-385/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-345/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-345/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-345/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-345/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-345/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-345/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-345/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-345/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-345/trainer_state.json (deflated 79%)
#   adding: content/chatbot_model/checkpoint-345/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-390/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-390/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-390/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-390/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-390/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-390/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-390/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-390/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-390/trainer_state.json (deflated 79%)
#   adding: content/chatbot_model/checkpoint-390/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-380/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-380/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-380/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-380/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-380/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-380/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-380/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-380/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-380/trainer_state.json (deflated 79%)
#   adding: content/chatbot_model/checkpoint-380/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-425/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-425/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-425/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-425/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-425/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-425/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-425/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-425/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-425/trainer_state.json (deflated 80%)
#   adding: content/chatbot_model/checkpoint-425/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-10/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-10/adapter_model.safetensors (deflated 8%)
#   adding: content/chatbot_model/checkpoint-10/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-10/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-10/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-10/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-10/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-10/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-10/trainer_state.json (deflated 57%)
#   adding: content/chatbot_model/checkpoint-10/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-90/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-90/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-90/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-90/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-90/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-90/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-90/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-90/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-90/trainer_state.json (deflated 70%)
#   adding: content/chatbot_model/checkpoint-90/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-220/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-220/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-220/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-220/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-220/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-220/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-220/scheduler.pt (deflated 62%)
#   adding: content/chatbot_model/checkpoint-220/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-220/trainer_state.json (deflated 77%)
#   adding: content/chatbot_model/checkpoint-220/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-470/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-470/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-470/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-470/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-470/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-470/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-470/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-470/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-470/trainer_state.json (deflated 80%)
#   adding: content/chatbot_model/checkpoint-470/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-430/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-430/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-430/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-430/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-430/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-430/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-430/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-430/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-430/trainer_state.json (deflated 80%)
#   adding: content/chatbot_model/checkpoint-430/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-395/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-395/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-395/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-395/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-395/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-395/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-395/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-395/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-395/trainer_state.json (deflated 79%)
#   adding: content/chatbot_model/checkpoint-395/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-160/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-160/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-160/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-160/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-160/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-160/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-160/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-160/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-160/trainer_state.json (deflated 75%)
#   adding: content/chatbot_model/checkpoint-160/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-265/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-265/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-265/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-265/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-265/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-265/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-265/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-265/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-265/trainer_state.json (deflated 77%)
#   adding: content/chatbot_model/checkpoint-265/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-500/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-500/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-500/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-500/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-500/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-500/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-500/scheduler.pt (deflated 62%)
#   adding: content/chatbot_model/checkpoint-500/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-500/trainer_state.json (deflated 80%)
#   adding: content/chatbot_model/checkpoint-500/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-155/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-155/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-155/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-155/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-155/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-155/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-155/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-155/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-155/trainer_state.json (deflated 74%)
#   adding: content/chatbot_model/checkpoint-155/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-180/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-180/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-180/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-180/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-180/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-180/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-180/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-180/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-180/trainer_state.json (deflated 75%)
#   adding: content/chatbot_model/checkpoint-180/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-80/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-80/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-80/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-80/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-80/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-80/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-80/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-80/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-80/trainer_state.json (deflated 69%)
#   adding: content/chatbot_model/checkpoint-80/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-315/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-315/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-315/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-315/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-315/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-315/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-315/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-315/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-315/trainer_state.json (deflated 78%)
#   adding: content/chatbot_model/checkpoint-315/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-70/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-70/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-70/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-70/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-70/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-70/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-70/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-70/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-70/trainer_state.json (deflated 68%)
#   adding: content/chatbot_model/checkpoint-70/adapter_config.json (deflated 55%)
#   adding: content/chatbot_model/checkpoint-65/ (stored 0%)
#   adding: content/chatbot_model/checkpoint-65/adapter_model.safetensors (deflated 7%)
#   adding: content/chatbot_model/checkpoint-65/optimizer.pt (deflated 11%)
#   adding: content/chatbot_model/checkpoint-65/rng_state.pth (deflated 26%)
#   adding: content/chatbot_model/checkpoint-65/training_args.bin (deflated 53%)
#   adding: content/chatbot_model/checkpoint-65/README.md (deflated 66%)
#   adding: content/chatbot_model/checkpoint-65/scheduler.pt (deflated 61%)
#   adding: content/chatbot_model/checkpoint-65/scaler.pt (deflated 64%)
#   adding: content/chatbot_model/checkpoint-65/trainer_state.json (deflated 67%)
#   adding: content/chatbot_model/checkpoint-65/adapter_config.json (deflated 55%)
